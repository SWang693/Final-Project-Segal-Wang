# %% [markdown]
# # Submetric - Parks
#
# A key component to fun in a neighborhood is the availabilty and quality of public zones dedicated to fun - i.e. parks. Using a combination of a datasets on parks, I will develop a metric for determining the best neighborhood for parks in Pittsburgh.

# %% [markdown]
# ## Metric
#
# The best neighborhood for parks depends on two factors, the number of parks in a neighborhood and the total area of parks. Each is valuable because it determines how many parks are available for use as well as how much space is available. We will multiply these two factors to generate our metric.

# %% [markdown]
# ## Analysis

# %% [markdown]
# First we import pandas and import our data.

# %%
# import pandas
import pandas as pd
import geopandas as gp
# %matplotlib inline

# import our datasets
parks = pd.read_csv("parks.csv")
parks2 = pd.read_csv("parks2.csv")

# %% [markdown]
# The first parks dataset includes data on the dimensions of the park.

# %%
parks.sample(5)
# Out:
#      objectid_1  objectid   acreage          sqft            final_cat type  \
# 211        1414       226  1.721324  74980.569354      Riverfront Park  RVR
# 31         1233       212  1.053451  45888.125590       Community Park   CP
# 133        1335       136  0.156243   6805.915946  Beautification Site  BTF
# 109        1311        16  0.278235  12119.861209  Beautification Site  BTF
# 147        1349       128  0.079060   3443.843021  Beautification Site  BTF
#
#      sector                      origpkname                      updatepknm  \
# 211      16                             NaN  Monongahela Wharf Landing Park
# 31        4        Tuxedo Street Skate Park        Tuxedo Street Skate Park
# 133      12         Negley-Collins Triangle         Negley-Collins Triangle
# 109      14               Bates St Triangle               Bates St Triangle
# 147      10  Monitor St and St Phil Islands  Monitor St and St Phil Islands
#
#                          alterntnam  ...  \
# 211                             NaN  ...
# 31         Tuxedo Street Skate Park  ...
# 133         Negley-Collins Triangle  ...
# 109               Bates St Triangle  ...
# 147  Monitor St and St Phil Islands  ...
#
#                                  globalid     created_user  \
# 211                                   NaN  pgh.dcp.allisot
# 31   d54d5c1a-2212-4d36-8d4a-11f7d43e3c7f  pgh.dcp.allisot
# 133  6800cfe2-5d26-4f19-a71f-8e507978ad94  pgh.dcp.allisot
# 109  88d2aac9-ab97-4fe4-95de-093659d7a5fd  pgh.dcp.allisot
# 147  8b16bb3a-205c-4812-aa9a-ad87e31e2a78  pgh.dcp.allisot
#
#                          created_date last_edited_user  \
# 211  2022-08-24T16:53:03.812000+00:00  pgh.dcp.allisot
# 31   2022-08-24T16:53:03.812000+00:00  pgh.dcp.allisot
# 133  2022-08-24T16:53:03.812000+00:00  pgh.dcp.allisot
# 109  2022-08-24T16:53:03.812000+00:00  pgh.dcp.allisot
# 147  2022-08-24T16:53:03.812000+00:00  pgh.dcp.allisot
#
#                      last_edited_date maintenanceresponsibility    dpw_ac  \
# 211  2022-08-24T16:53:03.812000+00:00          Parks - Northern  1.721324
# 31   2022-08-24T16:53:03.812000+00:00           Parks - Western  1.053451
# 133  2022-08-24T16:53:03.812000+00:00              2nd Division  0.156243
# 109  2022-08-24T16:53:03.812000+00:00              3rd Division  0.278235
# 147  2022-08-24T16:53:03.812000+00:00              3rd Division  0.079060
#
#                                globalid_1    shape_area shape_length
# 211  24b4942b-6152-422d-812b-78b175cdaed4  12039.253906  1782.096883
# 31   b9052479-b861-4b01-9e1f-b85e21748e01   7371.191406   402.696661
# 133  907c4800-a955-4013-bdbc-01be47ebd845   1093.683594   136.511014
# 109  a8eda734-ff98-4869-8902-dc99cf1f6312   1945.808594   172.882207
# 147  d8341ecd-7d27-4217-aa7e-99afd74937bd    552.761719   100.902895
#
# [5 rows x 22 columns]

# %% [markdown]
# Not all of the entries in this dataset are parks, and we don't need all of these columns.

# %%
# filter out only the entries that describe a park
parks = parks.loc[parks['final_cat'].str.contains("Park")]

# strip the columns down to just the park name and the acreage
parks = parks[['updatepknm','acreage']]

parks.sample(5)
# Out:
#                           updatepknm   acreage
# 59                      Larimer Park  1.513133
# 134           Manchester School Park  2.809611
# 6                       Pauline Park  1.217859
# 58    West End-Elliott Overlook Park  4.688868
# 2    Roland Lockridge Community Park  0.468682

# %% [markdown]
# Now that we have the acreage for each park, we need to know which neighborhood each park is in. However, the first parks dataset does not include which neighborhood each park is in. That's where the parks2 datasets comes in handy.

# %%
parks2.sample(5)
# Out:
#              id                  name                   type  \
# 29   1541097919    Brookline Monument      Monument/Memorial
# 192   691951672  Washburn Square Park                   Park
# 6    1596467340   Alpine Gardens Park                   Park
# 17   2014605692     Bates St Triangle  Traffic Island/Median
# 131   375307767      Monongahela Park                   Park
#
#     maintenance_responsibility  \
# 29                4th Division
# 192           Parks - Northern
# 6             Parks - Northern
# 17                3rd Division
# 131           Parks - Southern
#
#                                                  image        neighborhood  \
# 29                                                 NaN           Brookline
# 192  https://tools.wprdc.org/images/pittsburgh/park...  Marshall-Shadeland
# 6    https://tools.wprdc.org/images/pittsburgh/park...   Central Northside
# 17   https://tools.wprdc.org/images/pittsburgh/park...       South Oakland
# 131                                                NaN   South Side Slopes
#
#      council_district  ward        tract  public_works_division  pli_division  \
# 29                  4    19  42003191800                      5            19
# 192                 1    27  42003270400                      1            27
# 6                   6    25  42003250300                      1            25
# 17                  3     4  42003040900                      3             4
# 131                 3    16  42003160800                      3            16
#
#      police_zone fire_zone   latitude  longitude
# 29             6      4-26  40.391738 -80.017114
# 192            1      1-14  40.467056 -80.031151
# 6              1      1-21  40.457673 -80.012852
# 17             4      2-11  40.434821 -79.956270
# 131            3      4-22  40.421699 -79.966333

# %% [markdown]
# This dataset has a few columns we don't need, so let's strip it down.

# %%
parks2 = parks2[['name','neighborhood']]
parks2.sample(5)
# Out:
#                           name       neighborhood
# 21          Beechview Monument          Beechview
# 9                   Ammon Park  Bedford Dwellings
# 2                   Alcoa Park        North Shore
# 140  Nelson Mandela Peace Park           Garfield
# 33               Catalano Park      Spring Garden

# %% [markdown]
# Now we will combine the two datasets so we know which neighborhood each park is in as well as it's acreage.

# %%
# the park name columns need to have the same name to merge
parks = parks.rename(columns={'updatepknm':'name'})

# merges the data
parks = pd.merge(parks,parks2,how="left", on='name')
parks.sample(5)
# Out:
#                          name    acreage     neighborhood
# 63    Brookline Memorial Park  56.059359        Brookline
# 130               Cowley Park   4.223513        Troy Hill
# 13            Volunteers Park   8.592524          Carrick
# 46                 Dinan Park  14.263087  Stanton Heights
# 21   Tuxedo Street Skate Park   1.053451         Sheraden

# %% [markdown]
# Here we visualize the size of each park:

# %%
parks.head(40).plot.bar(x='name',title="Acreage of Each Park", figsize=(15,5))

# %% [markdown]
# Next we will sum up the acreage of the parks for each neighborhood.

# %%
total_acreage = parks.groupby('neighborhood')['acreage'].sum()
total_acreage.sort_values().tail(30).plot.bar(title="Total Acreage of Parks for Each Neighborhood", figsize=(15,7))

# %% [markdown]
# Then we count the number of parks per neighborhood.

# %%
num_of_parks = parks.groupby('neighborhood')['name'].count()
num_of_parks.sort_values().tail(30).plot.bar(title="Number of Parks for Each Neighborhood", figsize=(15,7))

# %% [markdown]
# Finally, we generate our metric by multiplying these two values.

# %%
metric = (num_of_parks * total_acreage)
metric.sort_values().tail(30).plot.bar(title="Best Neighborhood for Parks", figsize=(15,7))

# %%
metric.sort_values()
# Out:
# neighborhood
# West Oakland              0.053646
# Bluff                     0.108286
# Esplen                    0.132588
# Westwood                  0.344124
# Homewood West             0.428525
#                           ...
# Mount Washington        378.294610
# South Side Slopes       498.721701
# Perry North             520.405507
# Highland Park           766.037293
# Squirrel Hill South    3126.670986
# Length: 71, dtype: float64

# %%
# Import neighborhood geometry data
neighborhoods = gp.read_file("Neighborhoods/Neighborhoods_.shp")

# merge our metric data with the geometry
metric.name = "metric"
metric = neighborhoods.merge(metric, how='left', left_on='hood', right_on='neighborhood')

# plot a map, "metric" is the metric #
metric.plot(column="metric",
            cmap='OrRd',              
               edgecolor="white",        
               legend=True,              
               legend_kwds={'label': "Best Neighborhood For Parks"}, 
               figsize=(10, 5),         
               missing_kwds={"color": "lightgrey"} 
           )
